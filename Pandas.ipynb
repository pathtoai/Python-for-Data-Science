# %%
import pandas as pd
import numpy as np

# %%
array = np.array([1, 3, 5, np.nan, 6, 8])
print(array)
# Out:
# [ 1.  3.  5. nan  6.  8.]

# %% [markdown]
# ## Series.

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])

# %%
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %% [markdown]
# ## DataFrame

# %%
school = {"Students" : ["Ashish" , "Ram" , "Rahul", "Vikram" , "Raghav"] , 
          "Class" : ["10" , "12" ,"10" , "11" , "5"],
         "Marks" : [90, 80,70,88,98]}

# %%
df = pd.DataFrame(school)
df
# Out:
#   Students Class  Marks
# 0   Ashish    10     90
# 1      Ram    12     80
# 2    Rahul    10     70
# 3   Vikram    11     88
# 4   Raghav     5     98

# %%
df.columns
# Out:
# Index(['Students', 'Class', 'Marks'], dtype='object')

# %% [markdown]
# ## Read a CSV file

# %%
data = pd.read_csv("uberdrive.csv")

# %%
data.head()
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*
# 0     5.1   Meal/Entertain
# 1     5.0              NaN
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit

# %%
data.tail()
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*        PURPOSE*
# 1151  Unknown Location      3.9  Temporary Site
# 1152  Unknown Location     16.2         Meeting
# 1153           Gampaha      6.4  Temporary Site
# 1154         Ilukwatta     48.2  Temporary Site
# 1155               NaN  12204.7             NaN

# %%
data.dtypes
# Out:
# START_DATE*     object
# END_DATE*       object
# CATEGORY*       object
# START*          object
# STOP*           object
# MILES*         float64
# PURPOSE*        object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   START_DATE*  1156 non-null   object
#  1   END_DATE*    1155 non-null   object
#  2   CATEGORY*    1155 non-null   object
#  3   START*       1155 non-null   object
#  4   STOP*        1155 non-null   object
#  5   MILES*       1156 non-null   float64
#  6   PURPOSE*     653 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB

# %%
data.columns = ['START_DATE', 'END_DATE', 'CATEGORY', 'START', 'STOP', 'MILES','PURPOSE']

# %%
data.head()
# Out:
#        START_DATE        END_DATE  CATEGORY        START             STOP  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES          PURPOSE
# 0    5.1   Meal/Entertain
# 1    5.0              NaN
# 2    4.8  Errand/Supplies
# 3    4.7          Meeting
# 4   63.7   Customer Visit

# %% [markdown]
# ## Check Data Size and Shape

# %%
print( "No of rows in my dataframe is ",  data.shape[0]) 
print("No of columns in my dataframe is ", data.shape[1])
# Out:
# No of rows in my dataframe is  1156
# No of columns in my dataframe is  7

# %% [markdown]
# ## Data Selection

# %%
data[['START_DATE' ,'END_DATE' ,'CATEGORY']][0:5]
# Out:
#        START_DATE        END_DATE  CATEGORY
# 0  1/1/2016 21:11  1/1/2016 21:17  Business
# 1   1/2/2016 1:25   1/2/2016 1:37  Business
# 2  1/2/2016 20:25  1/2/2016 20:38  Business
# 3  1/5/2016 17:31  1/5/2016 17:45  Business
# 4  1/6/2016 14:42  1/6/2016 15:49  Business

# %%
new_data= data[0:data.shape[0]-1]

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1155 entries, 0 to 1154
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   START_DATE  1155 non-null   object
#  1   END_DATE    1155 non-null   object
#  2   CATEGORY    1155 non-null   object
#  3   START       1155 non-null   object
#  4   STOP        1155 non-null   object
#  5   MILES       1155 non-null   float64
#  6   PURPOSE     653 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB

# %% [markdown]
# ## row , column selection using loc and iloc

# %%
## loc

data.loc[0:10, ["START_DATE","END_DATE"]]
# Out:
#          START_DATE         END_DATE
# 0    1/1/2016 21:11   1/1/2016 21:17
# 1     1/2/2016 1:25    1/2/2016 1:37
# 2    1/2/2016 20:25   1/2/2016 20:38
# 3    1/5/2016 17:31   1/5/2016 17:45
# 4    1/6/2016 14:42   1/6/2016 15:49
# 5    1/6/2016 17:15   1/6/2016 17:19
# 6    1/6/2016 17:30   1/6/2016 17:35
# 7    1/7/2016 13:27   1/7/2016 13:33
# 8    1/10/2016 8:05   1/10/2016 8:25
# 9   1/10/2016 12:17  1/10/2016 12:44
# 10  1/10/2016 15:08  1/10/2016 15:51

# %%
## iloc

data.iloc[0:10, 0:2]
# Out:
#         START_DATE         END_DATE
# 0   1/1/2016 21:11   1/1/2016 21:17
# 1    1/2/2016 1:25    1/2/2016 1:37
# 2   1/2/2016 20:25   1/2/2016 20:38
# 3   1/5/2016 17:31   1/5/2016 17:45
# 4   1/6/2016 14:42   1/6/2016 15:49
# 5   1/6/2016 17:15   1/6/2016 17:19
# 6   1/6/2016 17:30   1/6/2016 17:35
# 7   1/7/2016 13:27   1/7/2016 13:33
# 8   1/10/2016 8:05   1/10/2016 8:25
# 9  1/10/2016 12:17  1/10/2016 12:44

# %% [markdown]
# # Data Sorting

# %%
data.head()
# Out:
#        START_DATE        END_DATE  CATEGORY        START             STOP  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES          PURPOSE
# 0    5.1   Meal/Entertain
# 1    5.0              NaN
# 2    4.8  Errand/Supplies
# 3    4.7          Meeting
# 4   63.7   Customer Visit

# %%
new_data.sort_values(by = "MILES", ascending = False)
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 269    3/25/2016 16:52   3/25/2016 22:22  Business             Latta
# 270    3/25/2016 22:54    3/26/2016 1:39  Business      Jacksonville
# 881   10/30/2016 15:22  10/30/2016 18:23  Business         Asheville
# 776    9/27/2016 21:01    9/28/2016 2:37  Business  Unknown Location
# 546    7/14/2016 16:39   7/14/2016 20:05  Business       Morrisville
# ...                ...               ...       ...               ...
# 945   11/12/2016 13:46  11/12/2016 13:50  Business           Central
# 1121  12/27/2016 12:53  12/27/2016 12:57  Business           Kar?chi
# 420     6/8/2016 17:16    6/8/2016 17:18  Business              Soho
# 44     1/26/2016 17:27   1/26/2016 17:29  Business              Cary
# 120    2/17/2016 16:38   2/17/2016 16:43  Business        Katunayaka
#
#                   STOP  MILES          PURPOSE
# 269       Jacksonville  310.3   Customer Visit
# ...

# %% [markdown]
# ## Logical conditions:

# %%
## Give me Start and Stop where MILES > 150
## Give me states and Cities where Covid count > 50K

# %%
new_data[(new_data["MILES"] > 150) & (new_data["MILES"] < 300)]
# Out:
#            START_DATE          END_DATE  CATEGORY             START  \
# 270   3/25/2016 22:54    3/26/2016 1:39  Business      Jacksonville
# 297    4/2/2016 19:38    4/2/2016 22:36  Business      Jacksonville
# 299     4/3/2016 2:00     4/3/2016 4:16  Business          Florence
# 546   7/14/2016 16:39   7/14/2016 20:05  Business       Morrisville
# 559   7/17/2016 12:20   7/17/2016 15:25  Personal             Boone
# 727   8/27/2016 16:15   8/27/2016 19:13  Business  Unknown Location
# 776   9/27/2016 21:01    9/28/2016 2:37  Business  Unknown Location
# 881  10/30/2016 15:22  10/30/2016 18:23  Business         Asheville
#
#                  STOP  MILES         PURPOSE
# 270         Kissimmee  201.0         Meeting
# 297         Ridgeland  174.2  Customer Visit
# 299              Cary  159.3         Meeting
# 546        Banner Elk  195.3             NaN
# 559              Cary  180.2         Commute
# 727  Unknown Location  156.9             NaN
# ...

# %%
new_data[(new_data["PURPOSE"] == "Customer Visit") & (new_data["MILES"] > 150)]
# Out:
#           START_DATE         END_DATE  CATEGORY         START          STOP  \
# 269  3/25/2016 16:52  3/25/2016 22:22  Business         Latta  Jacksonville
# 297   4/2/2016 19:38   4/2/2016 22:36  Business  Jacksonville     Ridgeland
#
#      MILES         PURPOSE
# 269  310.3  Customer Visit
# 297  174.2  Customer Visit

# %% [markdown]
# ## Missing Values

# %%
## Check Missing Values

data.isna().any()
# Out:
# START_DATE    False
# END_DATE       True
# CATEGORY       True
# START          True
# STOP           True
# MILES         False
# PURPOSE        True
# dtype: bool

# %%
## Check How many and which column has missing values

data.isna().sum()
# Out:
# START_DATE      0
# END_DATE        1
# CATEGORY        1
# START           1
# STOP            1
# MILES           0
# PURPOSE       503
# dtype: int64

# %%
data.isnull().sum()
# Out:
# START_DATE      0
# END_DATE        1
# CATEGORY        1
# START           1
# STOP            1
# MILES           0
# PURPOSE       503
# dtype: int64

# %%
## How to deal with them 
data.dropna(inplace = True)

# %%
data
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# 5       1/6/2016 17:15    1/6/2016 17:19  Business   West Palm Beach
# ...                ...               ...       ...               ...
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Kar?chi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                   STOP  MILES          PURPOSE
# 0          Fort Pierce    5.1   Meal/Entertain
# ...

# %% [markdown]
# ## Mathematical operation

# %% [markdown]
# ### Categorical Variable

# %%
## Categorical Variable

data['CATEGORY'].unique()
# Out:
# array(['Business', 'Personal'], dtype=object)

# %%
data['PURPOSE'].unique()
# Out:
# array(['Meal/Entertain', 'Errand/Supplies', 'Meeting', 'Customer Visit',
#        'Temporary Site', 'Between Offices', 'Charity ($)', 'Commute',
#        'Moving', 'Airport/Travel'], dtype=object)

# %%
data['CATEGORY'].value_counts()
# Out:
# Business    647
# Personal      6
# Name: CATEGORY, dtype: int64

# %%
data['PURPOSE'].value_counts()
# Out:
# Meeting            187
# Meal/Entertain     160
# Errand/Supplies    128
# Customer Visit     101
# Temporary Site      50
# Between Offices     18
# Moving               4
# Airport/Travel       3
# Charity ($)          1
# Commute              1
# Name: PURPOSE, dtype: int64

# %% [markdown]
# ### Numerical data

# %%
data['MILES'].sum()
# Out:
# 7311.200000000001

# %%
data['MILES'].mean()
# Out:
# 11.196324655436444

# %%
data['MILES'].std()
# Out:
# 22.986428750819957

# %%
data['MILES'].var()
# Out:
# 528.3759067165223

# %% [markdown]
# ## Grouping of data

# %%
data.groupby("CATEGORY")["MILES"].mean()
# Out:
# CATEGORY
# Business    10.970170
# Personal    35.583333
# Name: MILES, dtype: float64

# %%
data.groupby(["CATEGORY","PURPOSE"])["MILES"].sum()
# Out:
# CATEGORY  PURPOSE
# Business  Airport/Travel       16.5
#           Between Offices     197.0
#           Customer Visit     2089.5
#           Errand/Supplies     508.0
#           Meal/Entertain      911.7
#           Meeting            2851.3
#           Temporary Site      523.7
# Personal  Charity ($)          15.1
#           Commute             180.2
#           Moving               18.2
# Name: MILES, dtype: float64

# %% [markdown]
#  ## Joining

# %%
pd.concat([data,new_data,data])
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# 5       1/6/2016 17:15    1/6/2016 17:19  Business   West Palm Beach
# ...                ...               ...       ...               ...
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Kar?chi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                   STOP  MILES          PURPOSE
# 0          Fort Pierce    5.1   Meal/Entertain
# ...

# %% [markdown]
# ## Joins

# %% [markdown]
# “I have two different tables in Python but I’m not sure how to join them. What criteria should I consider? What are the different ways I can join these tables?”
#
# Inner Join in Pandas
#
# Full Join in Pandas
#
# Left Join in Pandas
#
# Right Join in Pandas
#
# ####################

# %% [markdown]
# #### Inner Join in Pandas
# ![image.png](attachment:637e26a3-ed7f-4dac-a871-7b7c956b4711.png)

# %%
import pandas as pd
product=pd.DataFrame({
    'Product_ID':[101,102,103,104,105,106,107],
    'Product_name':['Watch','Bag','Shoes','Smartphone','Books','Oil','Laptop'],
    'Category':['Fashion','Fashion','Fashion','Electronics','Study','Grocery','Electronics'],
    'Price':[299.0,1350.50,2999.0,14999.0,145.0,110.0,79999.0],
    'Seller_City':['Delhi','Mumbai','Chennai','Kolkata','Delhi','Chennai','Bengalore']
})
customer=pd.DataFrame({
    'id':[1,2,3,4,5,6,7,8,9],
    'name':['Olivia','Aditya','Cory','Isabell','Dominic','Tyler','Samuel','Daniel','Jeremy'],
    'age':[20,25,15,10,30,65,35,18,23],
    'Product_ID':[101,0,106,0,103,104,0,0,107],
    'Purchased_Product':['Watch','NA','Oil','NA','Shoes','Smartphone','NA','NA','Laptop'],
    'City':['Mumbai','Delhi','Bangalore','Chennai','Chennai','Delhi','Kolkata','Delhi','Mumbai']
})

# %%
product
# Out:
#    Product_ID Product_name     Category    Price Seller_City
# 0         101        Watch      Fashion    299.0       Delhi
# 1         102          Bag      Fashion   1350.5      Mumbai
# 2         103        Shoes      Fashion   2999.0     Chennai
# 3         104   Smartphone  Electronics  14999.0     Kolkata
# 4         105        Books        Study    145.0       Delhi
# 5         106          Oil      Grocery    110.0     Chennai
# 6         107       Laptop  Electronics  79999.0   Bengalore

# %%
customer
# Out:
#    id     name  age  Product_ID Purchased_Product       City
# 0   1   Olivia   20         101             Watch     Mumbai
# 1   2   Aditya   25           0                NA      Delhi
# 2   3     Cory   15         106               Oil  Bangalore
# 3   4  Isabell   10           0                NA    Chennai
# 4   5  Dominic   30         103             Shoes    Chennai
# 5   6    Tyler   65         104        Smartphone      Delhi
# 6   7   Samuel   35           0                NA    Kolkata
# 7   8   Daniel   18           0                NA      Delhi
# 8   9   Jeremy   23         107            Laptop     Mumbai

# %%
#Select * from Table1 t1 inner join Table2 t2 t1.Product_ID = t2.Product_ID

# %%
pd.merge(product,customer,on=['Product_ID'])
# Out:
#    Product_ID Product_name     Category    Price Seller_City  id     name  \
# 0         101        Watch      Fashion    299.0       Delhi   1   Olivia
# 1         103        Shoes      Fashion   2999.0     Chennai   5  Dominic
# 2         104   Smartphone  Electronics  14999.0     Kolkata   6    Tyler
# 3         106          Oil      Grocery    110.0     Chennai   3     Cory
# 4         107       Laptop  Electronics  79999.0   Bengalore   9   Jeremy
#
#    age Purchased_Product       City
# 0   20             Watch     Mumbai
# 1   30             Shoes    Chennai
# 2   65        Smartphone      Delhi
# 3   15               Oil  Bangalore
# 4   23            Laptop     Mumbai

# %% [markdown]
# #### The leadership team now wants more details about the products sold. They want to know about all the products sold by the seller to the same city i.e., seller and customer both belong to the same city.

# %%
pd.merge(product,customer,how='inner',left_on=['Product_ID','Seller_City'],right_on=['Product_ID','City'])
# Out:
#    Product_ID Product_name Category   Price Seller_City  id     name  age  \
# 0         103        Shoes  Fashion  2999.0     Chennai   5  Dominic   30
#
#   Purchased_Product     City
# 0             Shoes  Chennai

# %% [markdown]
# #### Outer Join in Pandas
#
# ![image.png](attachment:db112eec-5654-4a32-bd05-4dec37d55169.png)

# %%
pd.merge(product,customer,on='Product_ID',how='outer')
# Out:
#     Product_ID Product_name     Category    Price Seller_City   id     name  \
# 0          101        Watch      Fashion    299.0       Delhi  1.0   Olivia
# 1          102          Bag      Fashion   1350.5      Mumbai  NaN      NaN
# 2          103        Shoes      Fashion   2999.0     Chennai  5.0  Dominic
# 3          104   Smartphone  Electronics  14999.0     Kolkata  6.0    Tyler
# 4          105        Books        Study    145.0       Delhi  NaN      NaN
# 5          106          Oil      Grocery    110.0     Chennai  3.0     Cory
# 6          107       Laptop  Electronics  79999.0   Bengalore  9.0   Jeremy
# 7            0          NaN          NaN      NaN         NaN  2.0   Aditya
# 8            0          NaN          NaN      NaN         NaN  4.0  Isabell
# 9            0          NaN          NaN      NaN         NaN  7.0   Samuel
# 10           0          NaN          NaN      NaN         NaN  8.0   Daniel
#
#      age Purchased_Product       City
# ...

# %%
pd.merge(product,customer,on='Product_ID',how='outer',indicator=True)
# Out:
#     Product_ID Product_name     Category    Price Seller_City   id     name  \
# 0          101        Watch      Fashion    299.0       Delhi  1.0   Olivia
# 1          102          Bag      Fashion   1350.5      Mumbai  NaN      NaN
# 2          103        Shoes      Fashion   2999.0     Chennai  5.0  Dominic
# 3          104   Smartphone  Electronics  14999.0     Kolkata  6.0    Tyler
# 4          105        Books        Study    145.0       Delhi  NaN      NaN
# 5          106          Oil      Grocery    110.0     Chennai  3.0     Cory
# 6          107       Laptop  Electronics  79999.0   Bengalore  9.0   Jeremy
# 7            0          NaN          NaN      NaN         NaN  2.0   Aditya
# 8            0          NaN          NaN      NaN         NaN  4.0  Isabell
# 9            0          NaN          NaN      NaN         NaN  7.0   Samuel
# 10           0          NaN          NaN      NaN         NaN  8.0   Daniel
#
#      age Purchased_Product       City      _merge
# ...

# %% [markdown]
# #### Left Join in Pandas
#
# ![image.png](attachment:f485ec7f-b53f-435c-9d54-99a03eae37ea.png)

# %%
pd.merge(product,customer,on='Product_ID',how='left')
# Out:
#    Product_ID Product_name     Category    Price Seller_City   id     name  \
# 0         101        Watch      Fashion    299.0       Delhi  1.0   Olivia
# 1         102          Bag      Fashion   1350.5      Mumbai  NaN      NaN
# 2         103        Shoes      Fashion   2999.0     Chennai  5.0  Dominic
# 3         104   Smartphone  Electronics  14999.0     Kolkata  6.0    Tyler
# 4         105        Books        Study    145.0       Delhi  NaN      NaN
# 5         106          Oil      Grocery    110.0     Chennai  3.0     Cory
# 6         107       Laptop  Electronics  79999.0   Bengalore  9.0   Jeremy
#
#     age Purchased_Product       City
# 0  20.0             Watch     Mumbai
# 1   NaN               NaN        NaN
# 2  30.0             Shoes    Chennai
# 3  65.0        Smartphone      Delhi
# 4   NaN               NaN        NaN
# 5  15.0               Oil  Bangalore
# 6  23.0            Laptop     Mumbai

# %% [markdown]
# #### Right Join in Pandas
#
# ![image.png](attachment:333a8f9c-5304-4b0d-a91f-26400c21a747.png)

# %%
pd.merge(product,customer,on='Product_ID',how='right')
# Out:
#    Product_ID Product_name     Category    Price Seller_City  id     name  \
# 0         101        Watch      Fashion    299.0       Delhi   1   Olivia
# 1           0          NaN          NaN      NaN         NaN   2   Aditya
# 2         106          Oil      Grocery    110.0     Chennai   3     Cory
# 3           0          NaN          NaN      NaN         NaN   4  Isabell
# 4         103        Shoes      Fashion   2999.0     Chennai   5  Dominic
# 5         104   Smartphone  Electronics  14999.0     Kolkata   6    Tyler
# 6           0          NaN          NaN      NaN         NaN   7   Samuel
# 7           0          NaN          NaN      NaN         NaN   8   Daniel
# 8         107       Laptop  Electronics  79999.0   Bengalore   9   Jeremy
#
#    age Purchased_Product       City
# 0   20             Watch     Mumbai
# 1   25                NA      Delhi
# 2   15               Oil  Bangalore
# 3   10                NA    Chennai
# 4   30             Shoes    Chennai
# ...

# %% [markdown]
# Now, you can say:
#
#
# ![image.png](attachment:b9b748d1-8f0b-4a55-825b-66ac9f82f4c6.png)
